# %% [markdown]
# <a href="https://colab.research.google.com/github/dtht2d/deep-learning/blob/main/codes/deep-neral-net/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %autosave 30
# Out:
# Autosaving every 30 seconds

# %% [markdown]
# # **Classify ECG Signals Using Long Short-Term Memory Networks**
#
# MATLAB example “Classify ECG Signals Using Long Short-Term Memory Networks” (https://www.mathworks.com/help/signal/ug/classify-ecg-signals-using-long-short-term-memory-networks.html Links to an external site.), up to “Improve the Performance with Feature Extraction”, and execute the code.
# # **Objective**
# - Python code
# - Change the network (e.g. number of bi-LSTM units) and training parameters to see if we can get better results than the default settings presented in the example.
# - Compare the results of at least two of your variants with the default setup.

# %% [markdown]
# # **I. Background**
# [Understanding LSTM and its diagrams](https://blog.mlreview.com/understanding-lstm-and-its-diagrams-37e2f46f1714)
#
# [Understanding LSTM Networks](http://colah.github.io/posts/2015-08-Understanding-LSTMs/)
#
# [Understanding LSTM -
# a tutorial into Long Short-Term Memory
# Recurrent Neural Networks](https://arxiv.org/pdf/1909.09586.pdf)
# ![Screenshot 2023-05-04 at 4.41.16 PM.png](data:image/png;base64,...)
# ### **Summary**
# A Long Short-Term Memory (LSTM) network is a type of recurrent neural network (RNN)
#
# Approach (the hybrid learning) designed to capture long-term dependencies in sequential data. It uses memory units with gating mechanisms to regulate the flow of information.
# Methods:
# - **input gate** controls the storage of new information, the forget gate determines which old information to discard
# - **output gate** controls the exposure of information to the network.
#
# Pro: LSTMs address the limitations of traditional RNNs by allowing the network to remember important information over longer periods, making them effective in tasks involving sequential, time dependency data such as speech recognition, language translation, etc.

# %% [markdown]
# # **II. Methods**

# %% [markdown]
# ### Install library

# %%
# !pip install wfdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wfdb
#   Downloading wfdb-4.1.1-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.22.4)
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.10.1)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.27.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.5.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2022.12.7)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.1

# %% [markdown]
# ## **1. Dataset**

# %% [markdown]
# [Open database physiological signal and clinical data for research purpose](https://physionet.org/about/database/)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Load a specific record from Long Term AF Database instead
# https://physionet.org/content/ltafdb/1.0.0/

# %%
import wfdb
#Load Long Term AF Database
record_list = wfdb.get_record_list('ltafdb', records='all')

#Choose the firt record
record_name =record_list[4]

# Load the ECG record
record = wfdb.rdrecord(record_name, pn_dir='ltafdb')
annotation = wfdb.rdann(record_name, 'atr', pn_dir='ltafdb')
# Extract the ECG signal and the annotation labels
ecg_signal = record.p_signal.flatten()
labels = annotation.symbol
# Print the available classes in the dataset
classes = set(labels)

# %%
print (classes)
# Out:
# {'V', 'N', '"', '+', 'A'}

# %% [markdown]
# **"** (Quotation Mark): This label is often used to indicate a non-beat annotation or an unclear or uncertain annotation. It signifies that the specific annotation is not classified as a normal beat or any other abnormality.
#
# **+** (Plus Sign): This label is typically used to indicate paced beats. Paced beats occur when the heart's electrical activity is artificially stimulated by a pacemaker device.
#
# **A** (Atrial Fibrillation): Atrial Fibrillation (AF) is a common type of cardiac arrhythmia characterized by irregular and rapid electrical impulses in the atria of the heart.
#
# **N** (Normal Beat): This label is used to indicate normal or sinus beats, which represent the normal electrical activity of the heart.
#
# **V** (Premature Ventricular Contraction): Premature Ventricular Contraction (PVC) is an abnormal heartbeat that occurs when the ventricles of the heart contract earlier than expected.

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
# Create a histogram of label occurrences
label_counts = {label: 0 for label in classes}
for label in labels:
    label_counts[label] += 1

# Plot the histogram
plt.bar(label_counts.keys(), label_counts.values())
plt.xlabel('Label')
plt.ylabel('Count')
plt.title('Label Occurrences')
plt.show()

# %%
import matplotlib.pyplot as plt
# Plot the histogram
plt.figure(figsize=(10, 4))
plt.hist(ecg_signal, bins=50)
plt.title('Histogram of ECG Signals')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a dictionary to map class labels to signal indices
class_signals = {}

for i, label in enumerate(labels):
    if label in class_signals:
        class_signals[label].append(i)
    else:
        class_signals[label] = [i]
#print(ecg_signal[class_signals['A']][:100])
# Print the signals belonging to each class
#for label, indices in class_signals.items():
    #print(f"Class '{label}': Signals {indices}")
#print (labels[1])
#print (ecg_signal[1])

# %%
# Assign names to the class labels
class_names = {
    'N': 'Normal Beat)',
    'A': 'Atrial Fibrillation',
    '"': 'Other Rhythm',
    '+': 'Paced Beat',
    'V': 'Premature Ventricular Contraction'
}
class_target = {'N': 'Normal Beat)', 'A': 'Atrial Fibrillation'}

for class_label in class_target:
    # Find the indices of the samples belonging to the current class
    class_indices = [i for i in range(len(class_signals))]

    # Take the first segment from the class
    segment_length= 4000
    x = [i for i in range(segment_length)]
    y_signals = ecg_signal[class_signals[class_label]]
    y = y_signals[:4000]
    # Plot the segment for the current class
    plt.plot(x, y)
    # Set the title and axis labels for the plot
    plt.title(class_target[class_label])
    plt.xlabel('Sample')
    plt.ylabel('Amplitude')
    # Show the plot
    plt.show()

# %%
from collections import Counter
label_counts = Counter(labels)
# Print the label counts
for label, count in label_counts.items():
    print(f"Label '{label}' occurs {count} times")
# Out:
# Label '+' occurs 95 times
# Label 'N' occurs 100153 times
# Label 'A' occurs 4505 times
# Label 'V' occurs 5 times
# Label '"' occurs 181 times
